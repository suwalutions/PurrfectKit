# %% [markdown]
# # PurrfectKit Usage

# %% [markdown]
# PurrfectKit is a Python library that maps Thai cat breeds to NLP techniques, providing tools for text processing, extraction, and transformation.
#
# Each class in the `purrfectmeow` module represents a Thai cat breed with a specific NLP function:
#
# `Kornja`: Content Chunking (breaking text into manageable segments)
#
# `WichienMaat`: Semantic Search (understanding query intent)
#
# `KhaoManee`: Embedding & Storage (converting text to vectors and storing)
#
# `Malet`: Text Extraction (isolating data from text)
#
# `Suphalaks`: Internal utilities

# %% [markdown]
# ## Installation

# %% [markdown]
# To use PurrfectKit, ensure you have Python 3.10 or higher. Clone the repository and install it in editable mode using pip:

# %%
git clone https://github.com/suwalutions/PurrfectKit.git
cd PurrfectKit
pip install -e .

# %% [markdown]
# ## Examples

# %% [markdown]
# The `Malet` class provides a versatile `loader` method to process files in various formats. Below are examples demonstrating its capabilities, grouped by loader type.

# %% [markdown]
# ### Available Loaders

# %% [markdown]
# The `Malet.loader` method supports the following loaders:

# %% [markdown]
# | Loader          | Description                                                  |
# |-----------------|--------------------------------------------------------------|
# | `MARKITDOWN`    | Converts content to Markdown using the MarkItDown library.   |
# | `DOCLING`       | Converts content to Markdown using the Docling library.      |
# | `PYTESSERACT`   | Performs OCR on images or PDFs using Tesseract.              |
# | `EASYOCR`       | Performs OCR on images or PDFs using EasyOCR.                |
# | `SURYAOCR`      | Performs OCR on images or PDFs using SuryaOCR.               |
# | `PYMUPDF`       | Extracts text from PDFs using PyMuPDF.                       |
# | `PYMUPDF_AS_TXT`| Extracts plain text from PDFs using PyMuPDF.                 |
# | `PANDAS_EXCEL`  | Reads Excel files into text or data structures using pandas. |
# | `PANDAS_CSV`    | Reads CSV files into text or data structures using pandas.   |

# %%
from purrfectmeow import Malet

# %% [markdown]
# ### Simple Loaders

# %% [markdown]
# Extract text or data from files using straightforward loaders like `PYMUPDF` or `PANDAS_EXCEL`.

# %%
# Extract text from a PDF using PyMuPDF
try:
    docs = Malet.loader("example.pdf", "example.pdf", loader="PYMUPDF")
    print("Extracted PDF text:", docs[:200])  # Print first 200 characters
except FileNotFoundError:
    print("Error: File 'example.pdf' not found.")
except ValueError as e:
    print(f"Error: {e}")

# Extract data from an Excel file using pandas
try:
    docs = Malet.loader("data.xlsx", "data.xlsx", loader="PANDAS_EXCEL")
    print("Excel data:", docs.head() if hasattr(docs, "head") else docs)
except FileNotFoundError:
    print("Error: File 'data.xlsx' not found.")
except ValueError as e:
    print(f"Error: {e}")

# %% [markdown]
# ### OCR Loaders

# %% [markdown]
# Use OCR loaders to extract text from images or scanned PDFs.

# %%
# Perform OCR on an image using EasyOCR
try:
    with open("scanned_image.png", "rb") as f:
        text = Malet.loader(f, "scanned_image.png", loader="EASYOCR")
        print("OCR text:", text[:200])  # Print first 200 characters
except FileNotFoundError:
    print("Error: File 'scanned_image.png' not found.")
except ValueError as e:
    print(f"Error: {e}")

# Perform OCR on a receipt image using SuryaOCR
try:
    with open("receipt.jpg", "rb") as f:
        text = Malet.loader(f, "receipt.jpg", loader="SURYAOCR")
        print("OCR text:", text[:200])  # Print first 200 characters
except FileNotFoundError:
    print("Error: File 'receipt.jpg' not found.")
except ValueError as e:
    print(f"Error: {e}")

# %% [markdown]
# ### Markdown Loaders

# %% [markdown]
# Convert files to Markdown format for structured text output.

# %%
# Convert a file to Markdown using MarkItDown
try:
    docs = Malet.loader("notes.md", "notes.md", loader="MARKITDOWN")
    print("Markdown output:", docs[:200])  # Print first 200 characters
except FileNotFoundError:
    print("Error: File 'notes.md' not found.")
except ValueError as e:
    print(f"Error: {e}")

# Convert a file to Markdown using Docling
try:
    docs = Malet.loader("document.md", "document.md", loader="DOCLING")
    print("Markdown output:", docs[:200])  # Print first 200 characters
except FileNotFoundError:
    print("Error: File 'document.md' not found.")
except ValueError as e:
    print(f"Error: {e}")
